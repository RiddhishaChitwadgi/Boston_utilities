# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cleaned_data.csv')
# Out:
# /var/folders/zn/frtcx_8d3mg0lvjd20vlbdh00000gn/T/ipykernel_85741/1139031434.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('cleaned_data.csv')

# %%
from IPython.display import display
display(df)
# Out:
#         Invoice_ID Account_Number Energy_Type_Name Invoice_Date   From_Date  \
# 0          6590186     9504656628            Steam   2014-12-01  2014-10-30
# 1          6737700    26442061003         Electric   2012-08-03  2012-07-03
# 2          6764410    25954341001         Electric   2012-11-16  2012-10-17
# 3          6764411    27828660012         Electric   2011-04-28  2011-03-30
# 4          6764412    25954531007         Electric   2014-10-16  2014-09-16
# ...            ...            ...              ...          ...         ...
# 638652    17666357     9504656628            Steam   2023-05-09  2023-03-31
# 638653    17666358     0112234264            Steam   2023-05-09  2023-03-31
# 638654    17666359     2639475825            Steam   2023-05-09  2023-03-31
# 638655    17666360     9365726085            Steam   2023-05-09  2023-03-31
# 638656    17673300   005154419491      Natural Gas   2021-09-30  2021-08-30
#
#            To_Date  Usage_Period_Days  Delivery_Cost  Supply_Cost  Total_Cost  \
# 0       2014-12-01                 32        2492.31         0.00     2492.31
# 1       2012-08-03                 31         307.61       462.19      769.80
# 2       2012-11-16                 30         278.37       316.14      594.51
# 3       2011-04-28                 29          12.60         5.43       18.03
# 4       2014-10-16                 30          21.56        19.02       40.58
# ...            ...                ...            ...          ...         ...
# 638652  2023-04-28                 28         148.06         0.00      148.06
# 638653  2023-04-28                 28        7625.30         0.00     7625.30
# 638654  2023-04-28                 28         518.22         0.00      518.22
# 638655  2023-04-28                 28       20753.91         0.00    20753.91
# 638656  2021-09-30                 31         139.14        12.58      151.72
#
#         ...    City    Zip     State_Name Abbreviation   Country_Name  \
# 0       ...  Boston   2108  Massachusetts           MA  United States
# 1       ...  Boston   2134  Massachusetts           MA  United States
# 2       ...  Boston   2119  Massachusetts           MA  United States
# 3       ...  Boston   2110  Massachusetts           MA  United States
# 4       ...  Boston   2119  Massachusetts           MA  United States
# ...     ...     ...    ...            ...          ...            ...
# 638652  ...  Boston  02108  Massachusetts           MA  United States
# 638653  ...  Boston  02201  Massachusetts           MA  United States
# 638654  ...  Boston  02201  Massachusetts           MA  United States
# 638655  ...  Boston  02117  Massachusetts           MA  United States
# 638656  ...  Boston  02119  Massachusetts           MA  United States
#
#                    Site_Name Currency              Code_Description  \
# 0                    Unknown      USD              Delivery Invoice
# 1           Smith Playground      USD  Supply and Delivery Invoices
# 2       Metered Streetlights      USD  Supply and Delivery Invoices
# 3                  Engine 10      USD  Supply and Delivery Invoices
# 4       Metered Streetlights      USD  Supply and Delivery Invoices
# ...                      ...      ...                           ...
# 638652               Unknown      USD              Delivery Invoice
# 638653               Unknown      USD              Delivery Invoice
# 638654               Unknown      USD              Delivery Invoice
# 638655               Unknown      USD              Delivery Invoice
# 638656                 Mason      USD  Supply and Delivery Invoices
#
#        Department_Name  Year
# 0                  PMD  2014
# 1                PARKS  2012
# 2                  PWD  2012
# 3                  BFD  2011
# 4                  PWD  2014
# ...                ...   ...
# 638652             PMD  2023
# 638653             PMD  2023
# 638654             PMD  2023
# 638655             BPL  2023
# 638656             BPS  2021
#
# [638657 rows x 22 columns]

# %%
df.head()
# Out:
#    Invoice_ID Account_Number Energy_Type_Name Invoice_Date   From_Date  \
# 0     6590186     9504656628            Steam   2014-12-01  2014-10-30
# 1     6737700    26442061003         Electric   2012-08-03  2012-07-03
# 2     6764410    25954341001         Electric   2012-11-16  2012-10-17
# 3     6764411    27828660012         Electric   2011-04-28  2011-03-30
# 4     6764412    25954531007         Electric   2014-10-16  2014-09-16
#
#       To_Date  Usage_Period_Days  Delivery_Cost  Supply_Cost  Total_Cost  ...  \
# 0  2014-12-01                 32        2492.31         0.00     2492.31  ...
# 1  2012-08-03                 31         307.61       462.19      769.80  ...
# 2  2012-11-16                 30         278.37       316.14      594.51  ...
# 3  2011-04-28                 29          12.60         5.43       18.03  ...
# 4  2014-10-16                 30          21.56        19.02       40.58  ...
#
#      City   Zip     State_Name Abbreviation   Country_Name  \
# 0  Boston  2108  Massachusetts           MA  United States
# 1  Boston  2134  Massachusetts           MA  United States
# 2  Boston  2119  Massachusetts           MA  United States
# 3  Boston  2110  Massachusetts           MA  United States
# 4  Boston  2119  Massachusetts           MA  United States
#
#               Site_Name Currency              Code_Description  \
# 0               Unknown      USD              Delivery Invoice
# 1      Smith Playground      USD  Supply and Delivery Invoices
# 2  Metered Streetlights      USD  Supply and Delivery Invoices
# 3             Engine 10      USD  Supply and Delivery Invoices
# 4  Metered Streetlights      USD  Supply and Delivery Invoices
#
#   Department_Name  Year
# 0             PMD  2014
# 1           PARKS  2012
# 2             PWD  2012
# 3             BFD  2011
# 4             PWD  2014
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Invoice_ID', 'Account_Number', 'Energy_Type_Name', 'Invoice_Date',
#        'From_Date', 'To_Date', 'Usage_Period_Days', 'Delivery_Cost',
#        'Supply_Cost', 'Total_Cost', 'Total_Consumption', 'Street_Address',
#        'City', 'Zip', 'State_Name', 'Abbreviation', 'Country_Name',
#        'Site_Name', 'Currency', 'Code_Description', 'Department_Name', 'Year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 638657 entries, 0 to 638656
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Invoice_ID         638657 non-null  int64
#  1   Account_Number     638657 non-null  object
#  2   Energy_Type_Name   638657 non-null  object
#  3   Invoice_Date       638657 non-null  object
#  4   From_Date          638657 non-null  object
#  5   To_Date            638657 non-null  object
#  6   Usage_Period_Days  638657 non-null  int64
#  7   Delivery_Cost      638657 non-null  float64
#  8   Supply_Cost        638657 non-null  float64
#  9   Total_Cost         638657 non-null  float64
#  10  Total_Consumption  638657 non-null  float64
#  11  Street_Address     638657 non-null  object
#  12  City               638657 non-null  object
#  13  Zip                638657 non-null  object
#  14  State_Name         638657 non-null  object
#  15  Abbreviation       638657 non-null  object
#  16  Country_Name       638657 non-null  object
#  17  Site_Name          638657 non-null  object
#  18  Currency           638657 non-null  object
#  19  Code_Description   638657 non-null  object
#  20  Department_Name    638657 non-null  object
#  21  Year               638657 non-null  int64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 107.2+ MB

# %%
df.describe(include='all')
# Out:
#           Invoice_ID Account_Number Energy_Type_Name Invoice_Date   From_Date  \
# count   6.386570e+05         638657           638657       638657      638657
# unique           NaN           4791                5         3768        4212
# top              NaN    26436411008         Electric   2021-10-13  2021-06-14
# freq             NaN            916           508175         1630        1671
# mean    1.090865e+07            NaN              NaN          NaN         NaN
# std     3.822812e+06            NaN              NaN          NaN         NaN
# min     6.589679e+06            NaN              NaN          NaN         NaN
# 25%     6.944634e+06            NaN              NaN          NaN         NaN
# 50%     1.088891e+07            NaN              NaN          NaN         NaN
# 75%     1.417397e+07            NaN              NaN          NaN         NaN
# max     1.767330e+07            NaN              NaN          NaN         NaN
#
#            To_Date  Usage_Period_Days  Delivery_Cost    Supply_Cost  \
# count       638657      638657.000000  638657.000000  638657.000000
# unique        4187                NaN            NaN            NaN
# top     2021-07-14                NaN            NaN            NaN
# freq          1660                NaN            NaN            NaN
# mean           NaN          30.350606     533.029050     318.544543
# std            NaN           7.862332    3142.686819    2356.680540
# min            NaN        -456.000000  -30680.370000  -13565.060000
# 25%            NaN          29.000000      18.310000       0.000000
# 50%            NaN          30.000000      52.620000      16.430000
# 75%            NaN          32.000000     171.790000      84.550000
# max            NaN        1383.000000  284442.360000  224412.760000
#
#            Total_Cost  ...    City       Zip     State_Name  Abbreviation  \
# count   638657.000000  ...  638657  638657.0         638657        638657
# unique            NaN  ...      42     106.0              1             1
# top               NaN  ...  Boston    2119.0  Massachusetts            MA
# freq              NaN  ...  611073   37873.0         638657        638657
# mean       851.573593  ...     NaN       NaN            NaN           NaN
# std       4468.819571  ...     NaN       NaN            NaN           NaN
# min     -30680.370000  ...     NaN       NaN            NaN           NaN
# 25%         30.960000  ...     NaN       NaN            NaN           NaN
# 50%         95.980000  ...     NaN       NaN            NaN           NaN
# 75%        327.640000  ...     NaN       NaN            NaN           NaN
# max     318194.760000  ...     NaN       NaN            NaN           NaN
#
#          Country_Name             Site_Name Currency  \
# count          638657                638657   638657
# unique              1                  1411        1
# top     United States  Metered Streetlights      USD
# freq           638657                232716   638657
# mean              NaN                   NaN      NaN
# std               NaN                   NaN      NaN
# min               NaN                   NaN      NaN
# 25%               NaN                   NaN      NaN
# 50%               NaN                   NaN      NaN
# 75%               NaN                   NaN      NaN
# max               NaN                   NaN      NaN
#
#                     Code_Description Department_Name           Year
# count                         638657          638657  638657.000000
# unique                             4              40            NaN
# top     Supply and Delivery Invoices             PWD            NaN
# freq                          448352          247711            NaN
# mean                             NaN             NaN    2017.080979
# std                              NaN             NaN       3.585593
# min                              NaN             NaN    1969.000000
# 25%                              NaN             NaN    2014.000000
# 50%                              NaN             NaN    2017.000000
# 75%                              NaN             NaN    2020.000000
# max                              NaN             NaN    2023.000000
#
# [11 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Invoice_ID           0
# Account_Number       0
# Energy_Type_Name     0
# Invoice_Date         0
# From_Date            0
# To_Date              0
# Usage_Period_Days    0
# Delivery_Cost        0
# Supply_Cost          0
# Total_Cost           0
# Total_Consumption    0
# Street_Address       0
# City                 0
# Zip                  0
# State_Name           0
# Abbreviation         0
# Country_Name         0
# Site_Name            0
# Currency             0
# Code_Description     0
# Department_Name      0
# Year                 0
# dtype: int64

# %%
# Calculate the average total consumption over the years and group by year and energy type
average_consumption = df.groupby(['Year', 'Energy_Type_Name'])['Total_Consumption'].mean()

# Unstack the multi-index to create a pivot table
pivot_table = average_consumption.unstack()

pivot_table
# Out:
# Energy_Type_Name       Electric  Natural Gas          Oil        Steam  \
# Year
# 1969              233427.000000   103.340000          NaN          NaN
# 1970                        NaN          NaN   965.500000          NaN
# 2002               43476.100000          NaN          NaN          NaN
# 2010                4084.302561  5169.926667          NaN          NaN
# 2011                4244.968944  2688.256149  2292.204895  1307.272727
# 2012                3997.328702  2251.640958  1567.407955  1125.658537
# 2013                3953.192848  2589.847139  2278.374868   857.166667
# 2014                4033.264409  2412.397724  1673.155479  1072.714286
# 2015                3993.717388  2322.829321   544.822481   882.275556
# 2016                3982.988656  2044.587828   480.910256  1254.452381
# 2017                3917.570708  2066.137110   304.192411   974.245833
# 2018                3917.720943  2377.057878   251.578571  1470.132558
# 2019                4043.814643  1882.699083   295.064623   931.232653
# 2020                3731.204648  1922.668988   352.129742   952.883721
# 2021                3339.047722  2555.503165   277.947518  1006.266667
# 2022                3566.313997  2240.401178   347.346862   960.614286
# 2023                4467.294904  3675.122209          NaN   718.312500
#
# Energy_Type_Name         Water
# Year
# 1969                       NaN
# 1970                       NaN
# 2002                       NaN
# 2010                       NaN
# 2011               9302.459728
# 2012               9316.442694
# 2013               9905.596052
# 2014               9130.871139
# 2015               8654.700127
# 2016              10366.138864
# 2017               8137.608743
# 2018               8599.335390
# 2019               6700.974843
# 2020               5069.210087
# 2021               5631.465223
# 2022               6323.980967
# 2023               3204.958817

# %%
# Plot the graph
pivot_table.plot(kind='line', marker='o', figsize=(12, 6))
plt.xlabel('Year')
plt.ylabel('Average Total Consumption')
plt.title('Average Total Consumption over the Years, Grouped by Energy Type')
plt.legend(title='Energy Type')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
plt.hist(df['Energy_Type_Name'], bins=10, edgecolor='black')

# Add labels and title
plt.xlabel('Energy Type')
plt.ylabel('Occurence')
plt.title('Histogram of Energy Type')

# Display the histogram
plt.show()

# %%
non_numeric_columns = df.select_dtypes(exclude=['float64', 'int64']).columns
print("Non-numeric columns:", non_numeric_columns)
# Out:
# Non-numeric columns: Index(['Account_Number', 'Energy_Type_Name', 'Invoice_Date', 'From_Date',
#        'To_Date', 'Street_Address', 'City', 'Zip', 'State_Name',
#        'Abbreviation', 'Country_Name', 'Site_Name', 'Currency',
#        'Code_Description', 'Department_Name'],
#       dtype='object')

# %%
for col in non_numeric_columns:
    unique_values = df[col].unique()
    print(f"Unique values in {col}: {unique_values}")
# Out:
# Unique values in Account_Number: ['9504656628' '26442061003' '25954341001' ... '28489730029' '005153818786'
#  '30765750010']
# Unique values in Energy_Type_Name: ['Steam' 'Electric' 'Natural Gas' 'Water' 'Oil']
# Unique values in Invoice_Date: ['2014-12-01' '2012-08-03' '2012-11-16' ... '2023-04-04' '2023-05-11'
#  '2023-05-10']
# Unique values in From_Date: ['2014-10-30' '2012-07-03' '2012-10-17' ... '2023-04-06' '2023-04-07'
#  '2023-04-03']
# Unique values in To_Date: ['2014-12-01' '2012-08-03' '2012-11-16' ... '2023-04-16' '2023-05-05'
#  '2023-05-08']
# Unique values in Street_Address: ['City Hall Plaza' '235 Western Avenue' 'Washington St.sw.Eustis St.' ...
#  '384 WARREN ST 8G' '384 WARREN ST 6' '1663 COLUMBIA RD']
# Unique values in City: ['Boston' 'Dorchester' 'Roxbury' 'DORCHESTER' 'Waltham' 'Unknown'
#  'E BOSTON' 'BOSTON' 'boston' 'ROXBURY' 'E Boston' 'Hyde Park' 'S BOSTON'
#  'BRIGHTON' 'Brighton' 'W ROXBURY' 'HYDE PARK' 'ROXBRY XNG' 'ROSLINDALE'
#  'West Roxbury' 'CHARLESTOWN' 'JAMAICA PLAIN' 'ALLSTON' 'Jamaica Plain'
#  'Jamaica Pl' 'S Boston' 'Quincy' 'Charlestown' 'East Boston'
#  'South Boston' 'QUINCY' 'JAMAICA PL' 'Mattapan' 'Roslindale' 'W Roxbury'
#  'Dorcester' 'Hyde Park\t\t\t' 'Roxbury Crossing' 'Chestnut Hill'
#  'Allston' 'Bosgton' 'W. Roxbury']
# Unique values in Zip: [2108 2134 2119 2110 2128 2131 2132 2121 2136 2118 2135 2124 2127 2115
#  2129 2126 2125 2116 2171 2113 2210 2120 2201 2130 2114 2109 2122 2111
#  2215 2467 2199 2117 2446 2169 2203 2188 '02132' '02116' '02121' '02115'
#  '02118' '02136' '02130' '02125' '02119' '02135' '02122' '02127' '02124'
#  '02110' '02114' '02210' '02129' '02134' '02111' '02126' '02131' '02128'
#  '02120' '02113' '02109' '02199' '02215' '02108' '02201' '02446' '02171'
#  '02467' '02169' '02199     ' '02132     ' '02122     ' '02128     '
#  '02124     ' '02119     ' '02135     ' '02115     ' '02136     '
#  '02210     ' '02203' '02121     ' '02188' '02117' '02110     '
#  '02108-4301' '02146' '02215-2737' '02210-1226' '02111-2406' '02113-1914'
#  '02115-3005' '02210-1851' '02119-1216' '02219' '02116-4808' '02131-2522'
#  '02128-2511' '02126-1510' '02122-1223' '02130-3105' '02135-0000'
#  '02135-1944' '02135-1629' '2109' '02127-1805' '02120     ']
# Unique values in State_Name: ['Massachusetts']
# Unique values in Abbreviation: ['MA']
# Unique values in Country_Name: ['United States']
# Unique values in Site_Name: ['Unknown' 'Smith Playground' 'Metered Streetlights' ...
#  'Boston Fire Department' 'Boston Transportation Department' 'Childrens']
# Unique values in Currency: ['USD']
# Unique values in Code_Description: ['Delivery Invoice' 'Supply and Delivery Invoices'
#  'Single Invoice with Delivery and Supply' 'Supply Invoice']
# Unique values in Department_Name: ['PMD' 'PARKS' 'PWD' 'BFD' 'BTD' 'BPS' 'BPD' 'BPL' 'BCYF' 'PROP MGMT'
#  'Arts& Culture' ' PARKS' 'Arts&Culture' 'DND' 'COB' '119' 'ISD' 'Parks'
#  'PARK' 'Park' 'UNKNOWN' 'BPHC' '?DND' '1' 'PARKS ' 'PARKK'
#  'City of Boston ' ' PWD' 'Parcels 03711002' '?Parks' 'BPSC' 'SCH'
#  'Prop Mgmt' 'COB ' 'MOH' ' BPS' 'CON' '2' 'COB PMD' 'COb Parks']

# %%
# Select only numeric columns
df_numeric = df.select_dtypes(include=['float64', 'int64'])

# %%
corr=df_numeric.corr()
corr
# Out:
#                    Invoice_ID  Usage_Period_Days  Delivery_Cost  Supply_Cost  \
# Invoice_ID           1.000000          -0.044264       0.030856     0.023592
# Usage_Period_Days   -0.044264           1.000000       0.017139    -0.003314
# Delivery_Cost        0.030856           0.017139       1.000000     0.306490
# Supply_Cost          0.023592          -0.003314       0.306490     1.000000
# Total_Cost           0.034141           0.010306       0.864879     0.742899
# Total_Consumption   -0.004052           0.013022       0.545959     0.648349
# Year                 0.931229          -0.039323       0.021778     0.023615
#
#                    Total_Cost  Total_Consumption      Year
# Invoice_ID           0.034141          -0.004052  0.931229
# Usage_Period_Days    0.010306           0.013022 -0.039323
# Delivery_Cost        0.864879           0.545959  0.021778
# Supply_Cost          0.742899           0.648349  0.023615
# Total_Cost           1.000000           0.725858  0.027768
# Total_Consumption    0.725858           1.000000 -0.008817
# Year                 0.027768          -0.008817  1.000000

# %%
np.random.seed(0)
sns.set()
ax = sns.heatmap(corr, cbar= True, linewidths=2,vmax=1, vmin=0, square=True, cmap='Blues')
plt.show()
