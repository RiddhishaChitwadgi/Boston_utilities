# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
mydata=pd.read_csv('cleaned_data.csv')
# Out:
# /var/folders/zn/frtcx_8d3mg0lvjd20vlbdh00000gn/T/ipykernel_86053/1385841523.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   mydata=pd.read_csv('cleaned_data.csv')

# %%
# Define the feature matrix X (input variables)
X = mydata[['Supply_Cost', 'Delivery_Cost', 'Total_Cost']]

# Define the target variable y (total consumption)
y = mydata['Total_Consumption'] 

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create a Gradient Boosting Regression model
model = GradientBoostingRegressor()

# Train the model on the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 283118671.72616893
# R-squared: 0.6620380590485215

# %%
# Plot the predicted values against the actual values
plt.scatter(y_test, y_pred)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--')  # Plot the 45-degree line
plt.xlabel('Actual Total Consumption')
plt.ylabel('Predicted Total Consumption')
plt.title('Gradient Boosting Regression - Actual vs Predicted')
plt.show()
